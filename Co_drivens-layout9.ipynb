# %%
import torch
import numpy as np
import os
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch import nn
import torch.optim as optim
import time
import scienceplots
import torchsummary

import dataset
import data_Preprocess 
import models
import uLoss
import Metrics

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print ('device = ',device)
seed = 123 #seed必须是int，可以自行设置
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
plt.style.use('science')
plt.rcParams['text.usetex'] = False
# Out:
# device =  cuda:0

# %%
param = {
    'mesh_size':[0.1,0.1],
    'structure_size':[10,10],
    'measurements_num':9,
    'device':device,
    'is_plotInputMap':False,
    'Lambda':0.0,
    'HS_region':torch.tensor(([[[1.5,2.5],[6.9,8.4]],# region_1
                               [[4.4,8.4],[7.2,8.0]],# region_2
                               [[0.6,1.6],[5.0,6.0]],# region_3(1)
                               [[0.6,3.1],[4.0,5.0]],# region_3(2)
                               [[1.0,4.0],[0.8,2.8]],# region_4
                               [[5.6,8.6],[1.3,4.9]]])),# region_5
    'BCs':['Neumann','Convection','Radiation','Radiation'],# top,bottom,left,right
    'Heat Transfer Rate':52,
    'Convective coe':10,
    'Emissivity':0.05,
    'q':15,
    'T_a':20,
    'BC_regular':True,
    'HS_regular':False,
    'Direchlet BC':20,
    'learning_rate': 0.02,
    'epochs': 20000,
    'dis_interval': 1000,
    'is_plotLoss':True,
    'is_plotResult':False,
    'layout': '_random'    
    
}

# %%
train_set = dataset.MyDataset('Train','Co-driven',param)
test_set = dataset.MyDataset('Test','Co-driven',param)
train_loader = torch.utils.data.DataLoader(dataset = train_set,
                                          batch_size = 32,
                                          shuffle = False)
test_loader = torch.utils.data.DataLoader(dataset = test_set,
                                          batch_size = 100,
                                          shuffle = False)
trues = data_Preprocess.get_Tfields('Test').unsqueeze(1)

# %%
Unet = models.UNet(in_channels=1, out_channels=1, factors=2,param=param).to(device)
loss_fn = uLoss.UncertaintyLoss(param)
train_losses_epoch,loss_inner_epoch,loss_neumann_epoch,loss_radiation_epoch,loss_convection_epoch,loss_hsd_epoch = models._Train(Unet,train_loader,loss_fn,param)
# Out:
# Traing Epoch: 0, learning_rate = 0.02
# loss = 34.978908, loss_hs = 34.978908, loss_inner = 0.002780
# loss component -> loss_neumann = 0.060487, loss_radiation = 1.272177, loss_convection = 4.107123
# Traing Epoch: 1000, learning_rate = 0.02
# loss = 2.009667, loss_hs = 0.477063, loss_inner = 0.001586
# loss component -> loss_neumann = 0.002223, loss_radiation = 0.019132, loss_convection = 0.055683
# Traing Epoch: 2000, learning_rate = 0.02
# loss = 1.714120, loss_hs = 0.354885, loss_inner = 0.000989
# loss component -> loss_neumann = 0.001308, loss_radiation = 0.013121, loss_convection = 0.045665
# Traing Epoch: 3000, learning_rate = 0.02
# loss = 1.464331, loss_hs = 0.232495, loss_inner = 0.000938
# loss component -> loss_neumann = 0.000862, loss_radiation = 0.008875, loss_convection = 0.028197
# Traing Epoch: 4000, learning_rate = 0.02
# loss = 1.523541, loss_hs = 0.269853, loss_inner = 0.000903
# loss component -> loss_neumann = 0.000845, loss_radiation = 0.009957, loss_convection = 0.034395
# Traing Epoch: 5000, learning_rate = 0.02
# loss = 1.433708, loss_hs = 0.218992, loss_inner = 0.000887
# loss component -> loss_neumann = 0.000887, loss_radiation = 0.008734, loss_convection = 0.027224
# Traing Epoch: 6000, learning_rate = 0.02
# loss = 1.316556, loss_hs = 0.170958, loss_inner = 0.000871
# loss component -> loss_neumann = 0.000635, loss_radiation = 0.006286, loss_convection = 0.022927
# Traing Epoch: 7000, learning_rate = 0.02
# loss = 1.561064, loss_hs = 0.276723, loss_inner = 0.000851
# loss component -> loss_neumann = 0.000646, loss_radiation = 0.010344, loss_convection = 0.039718
# Traing Epoch: 8000, learning_rate = 0.02
# loss = 1.394420, loss_hs = 0.207222, loss_inner = 0.000842
# loss component -> loss_neumann = 0.000646, loss_radiation = 0.007907, loss_convection = 0.027035
# Traing Epoch: 9000, learning_rate = 0.02
# loss = 1.475261, loss_hs = 0.235856, loss_inner = 0.000835
# loss component -> loss_neumann = 0.000842, loss_radiation = 0.008655, loss_convection = 0.031072
# Traing Epoch: 10000, learning_rate = 0.02
# loss = 1.283343, loss_hs = 0.163897, loss_inner = 0.000825
# loss component -> loss_neumann = 0.000615, loss_radiation = 0.005830, loss_convection = 0.020794
# Traing Epoch: 11000, learning_rate = 0.02
# loss = 1.315409, loss_hs = 0.175556, loss_inner = 0.000818
# loss component -> loss_neumann = 0.000711, loss_radiation = 0.006433, loss_convection = 0.023452
# Traing Epoch: 12000, learning_rate = 0.02
# loss = 1.497968, loss_hs = 0.274934, loss_inner = 0.000816
# loss component -> loss_neumann = 0.000668, loss_radiation = 0.009936, loss_convection = 0.037747
# Traing Epoch: 13000, learning_rate = 0.02
# loss = 1.404555, loss_hs = 0.210681, loss_inner = 0.000806
# loss component -> loss_neumann = 0.000912, loss_radiation = 0.007582, loss_convection = 0.030277
# Traing Epoch: 14000, learning_rate = 0.02
# loss = 1.391911, loss_hs = 0.211574, loss_inner = 0.000800
# loss component -> loss_neumann = 0.000840, loss_radiation = 0.008288, loss_convection = 0.025699
# Traing Epoch: 15000, learning_rate = 0.02
# loss = 1.949889, loss_hs = 0.558055, loss_inner = 0.000794
# loss component -> loss_neumann = 0.002283, loss_radiation = 0.019225, loss_convection = 0.072389
# Traing Epoch: 16000, learning_rate = 0.02
# loss = 1.505148, loss_hs = 0.267161, loss_inner = 0.000800
# loss component -> loss_neumann = 0.001024, loss_radiation = 0.009674, loss_convection = 0.035330
# Traing Epoch: 17000, learning_rate = 0.02
# loss = 1.676264, loss_hs = 0.372869, loss_inner = 0.000793
# loss component -> loss_neumann = 0.001914, loss_radiation = 0.013097, loss_convection = 0.042691
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 Unet = models.UNet(in_channels=1, out_channels=1, factors=2,param=param).to(device)
#       2 loss_fn = uLoss.UncertaintyLoss(param)
# ----> 3 train_losses_epoch,loss_inner_epoch,loss_neumann_epoch,loss_radiation_epoch,loss_convection_epoch,loss_hsd_epoch = models._Train(Unet,train_loader,loss_fn,param)
#
# File G:\4.ThermalSoureDistribution_PINNs\MixBCs_examples\Codes\models.py:154, in _Train(model, data_loader, loss_fn, param)
#     152 optimizer.zero_grad()
#     153 out = model(MPs.unsqueeze(1))
# --> 154 out = uLoss.Fill_withMeasurements(out,MPs,param)
#     155 #out = uLoss.Fill_withDirechletBC(out,param)
#     157 loss = loss_fn(HSD,out,epoch)
#
# File G:\4.ThermalSoureDistribution_PINNs\MixBCs_examples\Codes\uLoss.py:10, in Fill_withMeasurements(out, MP, param)
#       8 def Fill_withMeasurements(out,MP,param):
#       9     paths = data_Preprocess.getDataPath()
# ---> 10     MPsNames = data_Preprocess.findTargetFiles(paths,'Train',dataType='measurements')
#      11     for file in natsorted(MPsNames):
#      12         if str(param['measurements_num'])+'_points_measurements'+param['layout'] in file:
#
# File G:\4.ThermalSoureDistribution_PINNs\MixBCs_examples\Codes\data_Preprocess.py:20, in findTargetFiles(paths, setType, dataType, fileType)
#      18 matching_files = []
#      19 for root, dirs, files in os.walk(paths):
# ---> 20     for file in natsorted(files):
#      21         if (file.endswith(fileType)) and (setType in file) and (dataType in file):
#      22             matching_files.append(os.path.join(root, file))
#
# File ~\.conda\envs\myTorch_gpu\lib\site-packages\natsort\natsort.py:293, in natsorted(seq, key, reverse, alg)
#     291 if alg & ns.PRESORT:
#     292     seq = sorted(seq, reverse=reverse, key=str)
# --> 293 return sorted(seq, reverse=reverse, key=natsort_keygen(key, alg))
#
# File ~\.conda\envs\myTorch_gpu\lib\site-packages\natsort\utils.py:341, in natsort_key(val, key, string_func, bytes_func, num_func)
#     338     val = key(val)
#     340 if isinstance(val, (str, PurePath)):
# --> 341     return string_func(val)
#     342 elif isinstance(val, bytes):
#     343     return bytes_func(val)
#
# File ~\.conda\envs\myTorch_gpu\lib\site-packages\natsort\utils.py:520, in parse_string_factory.<locals>.func(x)
#     518 c = compose_input(b)  # Decompose unicode if using LOCALE
#     519 d = splitter(c)  # Split string into components.
# --> 520 e = filter(None, d)  # Remove empty strings.
#     521 f = component_transform(e)  # Apply transform on components.
#     522 g = sep_inserter(f, sep)  # Insert '' between numbers.
#
# KeyboardInterrupt:

# %%
#torch.save(Unet,'Layout_9_empirical_2.pt')

# %%
Unet = torch.load('Layout-9.pt')
for idx,data in enumerate(test_loader):
    MP = data[0].clone().detach().requires_grad_(True)
    HSD = data[1].clone().detach().requires_grad_(True)
    break
out = Unet(MP.unsqueeze(1))
out = uLoss.Fill_withMeasurements(out,MP,param)
#out = uLoss.HC_Convection(out,param)
#out = uLoss.Fill_withDirechletBC(out,param)
label = 38
print (Metrics.NMAE(out[],trues))
print (Metrics.RMSE(out.cpu(),trues.cpu()))
plt.figure(figsize=(16,16))
plt.subplot(2,3,1)
plt.imshow(trues[label][0].cpu().detach().numpy(),cmap='rainbow')
plt.title('True')
plt.colorbar()

plt.subplot(2,3,2)
plt.imshow(HSD[label].cpu().detach().numpy(),cmap='rainbow')
plt.colorbar()
plt.title('Heat Distribution')

plt.subplot(2,3,3)
plt.imshow(MP[label].cpu().detach().numpy(),cmap='rainbow')
plt.colorbar()
plt.title('Measurements')

plt.subplot(2,3,4)
plt.imshow(out[label][0].cpu().detach().numpy(),cmap='rainbow')
plt.colorbar()
plt.title('Prediction')

plt.subplot(2,3,5)
plt.imshow((trues[label][0]-out[label][0].cpu()).detach().numpy(),cmap='rainbow')
plt.colorbar()
plt.title('abs error')

plt.subplot(2,3,6)
plt.imshow(((trues[label][0]-out[label][0].cpu())/trues[label][0]).detach().numpy(),cmap='rainbow')
plt.colorbar()
plt.title('relative error')
plt.show()
# Out:
# tensor(0.0076, grad_fn=<MeanBackward0>)
# tensor(1.0976, grad_fn=<SqrtBackward0>)

# %%
from natsort import natsorted
def findTargetFiles(paths,setType,dataType,fileType='.txt'):# setType='Train' or 'Test';dataType= 'Tfield' or 'measurements'
    matching_files = []
    for root, dirs, files in os.walk(paths):
        for file in natsorted(files):
            if (file.endswith(fileType)) and (setType in file) and (dataType in file):
                matching_files.append(os.path.join(root, file))
    return matching_files
MPsNames = data_Preprocess.findTargetFiles(data_Preprocess.getDataPath(),'Train',dataType='measurements')
for file in natsorted(MPsNames):
    if str(param['measurements_num'])+'_points_measurements'+param['layout'] in file:
        MPName = file
        break
MPName
# Out:
# 'g:\\4.ThermalSoureDistribution_PINNs\\MixBCs_examples/Datas/Train_0_9_points_measurements_random.txt'

# %%
torch.save(Unet,'Layout-8.pt')

# %%
fig = plt.figure(figsize=(10,3))
plt.plot(range(param['epochs']),loss_hsd_epoch,'-o',color='blue',label='loss_hs',linewidth=0.5,markersize=2)
plt.legend()
plt.show()

fig = plt.figure(figsize=(10,3))
plt.plot(range(param['epochs']),loss_inner_epoch,'-o',color='black',label='loss_inner',linewidth=0.5,markersize=2)
plt.legend()
plt.show()

fig = plt.figure(figsize=(10,3))
plt.plot(range(param['epochs']),loss_neumann_epoch,'-o',color='blue',label='loss_neumann',linewidth=0.5,markersize=2)
plt.legend()
plt.show()

fig = plt.figure(figsize=(10,3))
plt.plot(range(param['epochs']),loss_radiation_epoch,'-.',color='red',label='loss_radiation',linewidth=0.5,markersize=2)
plt.legend()
plt.show()

fig = plt.figure(figsize=(10,3))
plt.plot(range(param['epochs']),loss_convection_epoch,'-*',color='black',label='loss_convection',linewidth=0.5,markersize=2)
plt.legend()
plt.show()

# %%
print ('loss_hs = {}'.format(uLoss.loss_HSD(out,HSD,param)))
print ('loss_inner = {}'.format(uLoss.loss_T_inner(out,param)))
print ('loss_neumann = {}'.format(uLoss.loss_neumann(out,param)))
print ('loss_radiation = {}'.format(uLoss.loss_radiation(out,param)))
print ('loss_convection = {}'.format(uLoss.loss_convection(out,param)))
# Out:
# loss_hs = 0.15309295058250427
# loss_inner = 0.0007880032062530518
# loss_neumann = 0.0005219927988946438
# loss_radiation = 0.0008571022772230208
# loss_convection = 0.005576829891651869

# %%
print ('loss_hs = {}'.format(uLoss.loss_HSD(trues,HSD,param)))
print ('loss_inner = {}'.format(uLoss.loss_T_inner(trues,param)))
print ('loss_neumann = {}'.format(uLoss.loss_neumann(trues,param)))
print ('loss_radiation = {}'.format(uLoss.loss_radiation(trues,param)))
print ('loss_convection = {}'.format(uLoss.loss_convection(trues,param)))
# Out:
# loss_hs = 0.0
# loss_inner = 0.0007096591871231794
# loss_neumann = 4.6441702579613775e-05
# loss_radiation = 0.0003792509960476309
# loss_convection = 0.0004917915211990476

# %%
def compute_temperature_gradient(temperature_field):
    # 获取温度场的维度
    nrows, ncols = temperature_field.shape
    
    # 初始化梯度场，每个点都有两个分量：x方向和y方向
    gradient_field = np.zeros((nrows, ncols, 2))
    
    # 计算内部点的梯度
    for i in range(1, nrows-1):
        for j in range(1, ncols-1):
            # x方向的温度梯度（水平方向）
            gradient_field[i, j, 0] = (temperature_field[i, j+1] - temperature_field[i, j-1]) / 2
            # y方向的温度梯度（垂直方向）
            gradient_field[i, j, 1] = (temperature_field[i+1, j] - temperature_field[i-1, j]) / 2

    # 处理边界，这里仅做示例，实际应用中可能需要根据边界条件进行适当调整
    # 左边界
    gradient_field[:, 0, 0] = temperature_field[:, 1] - temperature_field[:, 0]
    # 右边界
    gradient_field[:, -1, 0] = temperature_field[:, -1] - temperature_field[:, -2]
    # 上边界
    gradient_field[0, :, 1] = temperature_field[1, :] - temperature_field[0, :]
    # 下边界
    gradient_field[-1, :, 1] = temperature_field[-1, :] - temperature_field[-2, :]

    return gradient_field
a = out[label][0].view(101,101).cpu().detach().numpy()
temperature_field = a#np.random.rand(101, 101)
gradient_field = data_Preprocess.compute_temperature_gradient(temperature_field)

plt.imshow(gradient_field[:,:,0],cmap='rainbow')
plt.colorbar()
plt.title('T_gradient_x')
plt.show()
plt.imshow(gradient_field[:,:,1],cmap='rainbow')
plt.colorbar()
plt.title('T_gradient_y')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 3
#       1 a = out[label][0].view(101,101).cpu().detach().numpy()
#       2 temperature_field = a#np.random.rand(101, 101)
# ----> 3 gradient_field = data_Preprocess.compute_temperature_gradient(temperature_field)
#       5 plt.imshow(gradient_field[:,:,0],cmap='rainbow')
#       6 plt.colorbar()
#
# AttributeError: module 'data_Preprocess' has no attribute 'compute_temperature_gradient'

# %%
label = 0
plt.figure(figsize=(12,12))
plt.subplot(2,2,1)
plt.imshow(trues[label][0].cpu().detach().numpy(),cmap='rainbow')
plt.title('True')
plt.colorbar()

plt.subplot(2,2,2)
plt.imshow(HSD[label].cpu().detach().numpy(),cmap='rainbow')
plt.colorbar()
plt.title('Heat Distribution')

plt.subplot(2,2,3)
plt.imshow(out[label][0].cpu().detach().numpy(),cmap='rainbow')
plt.colorbar()
plt.title('Prediction')

plt.subplot(2,2,4)
plt.imshow((trues[label][0]-out[label][0].cpu()).detach().numpy(),cmap='rainbow')
plt.colorbar()
plt.title('abs error')
plt.show()

# %%
def loss_mixBC(out,param):
    hx = param['mesh_size'][0]
    hy = param['mesh_size'][1]
    MR = hy/hx
    T_ij = (2/MR**2+2)*out[:,0,-1,52:-1] - 2*out[:,0,-2,52:-1] - 1/MR**2*(out[:,0,-1,53:]+out[:,0,-1,51:-2])
    losses = torch.mean(torch.abs(T_ij))  
    if param['BC_regular'] == True:
        Reg = (out[:,0,-1,51:]-out[:,0,-2,51:])/hx
        print (Reg[0]**2)
        Reg = torch.zeros_like(Reg)
        losses = losses + 0.05*torch.mean(torch.exp(-75000*Reg**2))
    return  losses  
print ('loss_mixBC = {}'.format(loss_mixBC(trues,param)))
# Out:
# tensor([5.6316e+01, 2.2493e+01, 7.4720e+00, 3.5171e+00, 1.8894e+00, 1.1157e+00,
#         7.0131e-01, 4.6096e-01, 3.1326e-01, 2.1844e-01, 1.5561e-01, 1.1292e-01,
#         8.3279e-02, 6.2317e-02, 4.7296e-02, 3.6380e-02, 2.8339e-02, 2.2361e-02,
#         1.7836e-02, 1.4384e-02, 1.1704e-02, 9.6039e-03, 7.9204e-03, 6.5587e-03,
#         5.4429e-03, 4.5179e-03, 3.7393e-03, 3.0892e-03, 2.5394e-03, 2.0815e-03,
#         1.6942e-03, 1.3692e-03, 1.1040e-03, 8.8534e-04, 7.0492e-04, 5.6299e-04,
#         4.4662e-04, 3.5656e-04, 2.8558e-04, 2.2820e-04, 1.8443e-04, 1.5088e-04,
#         1.2493e-04, 1.0530e-04, 9.0223e-05, 7.9001e-05, 7.0431e-05, 6.5402e-05,
#         6.2354e-05, 6.1154e-05])
# loss_mixBC = 0.05434362590312958

# %%
def loss_convection(out,param):
    hx = param['mesh_size'][0]
    hy = param['mesh_size'][1]
    coe_x = 2*hx*param['Convective coe']/param['Heat Transfer Rate']
    coe_y = 2*hy*param['Convective coe']/param['Heat Transfer Rate']
    MR = hy/hx
    f_ij = []
    Reg = []
    if param['BCs'][0] == 'Convection': # top
        T_ij = (2*MR**2+2.0+coe_y)*out[:,0,1:-1,-1] - MR**2*(out[:,0,2:,-1]+out[:,0,0:-2,-1]) - 2*out[:,0,1:-1,-2] - coe_y*param['T_a']*torch.ones_like(out[:,0,1:-1,-1])
        f_ij.append(T_ij) 
        Reg.append((out[:,0,:,-1]-out[:,0,:,-2])/hy)           
        #print ('top')
    if param['BCs'][1] == 'Convection': # bottom
        T_ij = (2*MR**2+2.0+coe_y)*out[:,0,1:-1,0] - MR**2*(out[:,0,2:,0]+out[:,0,:-2,0]) - 2*out[:,0,1:-1,1] - coe_y*param['T_a']*torch.ones_like(out[:,0,1:-1,0])
        f_ij.append(T_ij)
        Reg.append((out[:,0,:,0]-out[:,0,:,1])/hy)
        print(Reg[0][0])
        print ('bottom')
    if param['BCs'][2] == 'Convection': # left
        T_ij = (2/MR**2+2.0+coe_x)*out[:,0,0,1:-1] - (1/MR**2)*(out[:,0,0,2:]+out[:,0,0,0:-2]) - 2*out[:,0,1,1:-1] - coe_x*param['T_a']*torch.ones_like(out[:,0,0,1:-1])
        f_ij.append(T_ij)
        Reg.append((out[:,0,0,:]-out[:,0,1,:])/hx)
        #print ('left')
    if param['BCs'][3] == 'Convection': # right
        T_ij = (2/MR**2+2.0+coe_x)*out[:,0,-1,1:-1] - (1/MR**2)*(out[:,0,-1,2:]+out[:,0,-1,0:-2]) - 2*out[:,0,-2,1:-1] - coe_x*param['T_a']*torch.ones_like(out[:,0,-1,1:-1])
        f_ij.append(T_ij)
        Reg.append((out[:,0,-1,:]-out[:,0,-2,:])/hx)    
    f_ij = torch.cat(f_ij)
    Reg = torch.cat(Reg)
    losses = torch.mean(torch.abs(f_ij))
    if param['BC_regular'] == True:
        #Reg = torch.zeros_like(Reg)
        losses = losses + 0.05*torch.mean(torch.exp(-75000 * Reg**2))
    return losses   
print ('loss_convection = {}'.format(loss_convection(trues,param)))
# Out:
# tensor([-8.3524, -8.3680, -8.3932, -8.4312, -8.4823, -8.5461, -8.6216, -8.7059,
#         -8.7948, -8.8823, -8.9622, -9.0296, -9.0819, -9.1190, -9.1432, -9.1578,
#         -9.1659, -9.1698, -9.1717, -9.1724, -9.1725, -9.1725, -9.1724, -9.1725,
#         -9.1727, -9.1730, -9.1737, -9.1747, -9.1756, -9.1769, -9.1782, -9.1789,
#         -9.1788, -9.1766, -9.1701, -9.1561, -9.1297, -9.0844, -9.0134, -8.9111,
#         -8.7756, -8.6092, -8.4194, -8.2156, -8.0077, -7.8032, -7.6070, -7.4214,
#         -7.2471, -7.0841, -6.9321, -6.7905, -6.6594, -6.5385, -6.4278, -6.3273,
#         -6.2367, -6.1558, -6.0840, -6.0207, -5.9649, -5.9158, -5.8724, -5.8336,
#         -5.7985, -5.7663, -5.7360, -5.7071, -5.6788, -5.6504, -5.6213, -5.5909,
#         -5.5583, -5.5230, -5.4840, -5.4403, -5.3908, -5.3340, -5.2684, -5.1922,
#         -5.1033, -4.9994, -4.8783, -4.7381, -4.5770, -4.3941, -4.1890, -3.9625,
#         -3.7160, -3.4517, -3.1719, -2.8795, -2.5771, -2.2668, -1.9508, -1.6306,
#         -1.3074, -0.9821, -0.6554, -0.3279,  0.0000])
# bottom
# loss_convection = 0.0012656645849347115

# %%
import numpy as np
import matplotlib.pyplot as plt

# 定义函数
def my_function(x):
    return np.exp(-20*x) - 1

# 生成 x 值
x_values = np.linspace(-0.01, 0.01, 1000)  # 生成在区间 [-0.1, 0.1] 内的 1000 个点

# 计算对应的 y 值
y_values = my_function(x_values)

# 绘制图形
plt.plot(x_values, y_values, label=r'$y = e^x - 1$')
plt.scatter([0.0001], [0.0001], color='red')  # 在 x=0.0001 处标记一个红点
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of $y = e^x - 1$')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def decreasing_function(x, k, n):
    return 1 / (1 + k * x)**n

# 生成一些示例数据
x_values = np.linspace(0, 0.02, 100)
k_value = 500  # 可以调整 k 的值
n_value = 4    # 可以调整 n 的值

# 计算函数值
y_values = decreasing_function(x_values, k_value, n_value)

# 绘制函数图像
plt.plot(x_values, y_values, label=f'1/(1+{k_value}x)^{n_value}')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--', label='y=0')
plt.axvline(0.01, color='red', linewidth=0.5, linestyle='--', label='x=0.01')
plt.axhline(0.0001, color='green', linewidth=0.5, linestyle='--', label='y=0.0001')

# 添加标签和标题
plt.title('Decreasing Function with Conditions')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# 显示图形
plt.show()

# %%
torchsummary.summary(Unet.cuda(), (1, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 224, 224]             160
#          GroupNorm-2         [-1, 16, 224, 224]              32
#               ReLU-3         [-1, 16, 224, 224]               0
#             Conv2d-4         [-1, 16, 224, 224]           2,320
#          GroupNorm-5         [-1, 16, 224, 224]              32
#               ReLU-6         [-1, 16, 224, 224]               0
#      _EncoderBlock-7         [-1, 16, 224, 224]               0
#          MaxPool2d-8         [-1, 16, 112, 112]               0
#             Conv2d-9         [-1, 32, 112, 112]           4,640
#         GroupNorm-10         [-1, 32, 112, 112]              64
#              ReLU-11         [-1, 32, 112, 112]               0
#            Conv2d-12         [-1, 32, 112, 112]           9,248
#         GroupNorm-13         [-1, 32, 112, 112]              64
#              ReLU-14         [-1, 32, 112, 112]               0
#     _EncoderBlock-15         [-1, 32, 112, 112]               0
#         MaxPool2d-16           [-1, 32, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          18,496
#         GroupNorm-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,928
#         GroupNorm-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#     _EncoderBlock-23           [-1, 64, 56, 56]               0
#         MaxPool2d-24           [-1, 64, 28, 28]               0
#            Conv2d-25          [-1, 128, 28, 28]          73,856
#         GroupNorm-26          [-1, 128, 28, 28]             256
#              ReLU-27          [-1, 128, 28, 28]               0
#            Conv2d-28          [-1, 128, 28, 28]         147,584
#         GroupNorm-29          [-1, 128, 28, 28]             256
#              ReLU-30          [-1, 128, 28, 28]               0
#     _EncoderBlock-31          [-1, 128, 28, 28]               0
#         AvgPool2d-32          [-1, 128, 14, 14]               0
#            Conv2d-33          [-1, 256, 14, 14]         295,168
#         GroupNorm-34          [-1, 256, 14, 14]             512
#              ReLU-35          [-1, 256, 14, 14]               0
#            Conv2d-36          [-1, 128, 14, 14]         295,040
#         GroupNorm-37          [-1, 128, 14, 14]             256
#              ReLU-38          [-1, 128, 14, 14]               0
#     _DecoderBlock-39          [-1, 128, 14, 14]               0
#            Conv2d-40          [-1, 128, 28, 28]         295,040
#         GroupNorm-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43           [-1, 64, 28, 28]          73,792
#         GroupNorm-44           [-1, 64, 28, 28]             128
#              ReLU-45           [-1, 64, 28, 28]               0
#     _DecoderBlock-46           [-1, 64, 28, 28]               0
#            Conv2d-47           [-1, 64, 56, 56]          73,792
#         GroupNorm-48           [-1, 64, 56, 56]             128
#              ReLU-49           [-1, 64, 56, 56]               0
#            Conv2d-50           [-1, 32, 56, 56]          18,464
#         GroupNorm-51           [-1, 32, 56, 56]              64
#              ReLU-52           [-1, 32, 56, 56]               0
#     _DecoderBlock-53           [-1, 32, 56, 56]               0
#            Conv2d-54         [-1, 32, 112, 112]          18,464
#         GroupNorm-55         [-1, 32, 112, 112]              64
#              ReLU-56         [-1, 32, 112, 112]               0
#            Conv2d-57         [-1, 16, 112, 112]           4,624
#         GroupNorm-58         [-1, 16, 112, 112]              32
#              ReLU-59         [-1, 16, 112, 112]               0
#     _DecoderBlock-60         [-1, 16, 112, 112]               0
#            Conv2d-61         [-1, 16, 224, 224]           4,624
#         GroupNorm-62         [-1, 16, 224, 224]              32
#              ReLU-63         [-1, 16, 224, 224]               0
#            Conv2d-64         [-1, 16, 224, 224]             272
#         GroupNorm-65         [-1, 16, 224, 224]              32
#              ReLU-66         [-1, 16, 224, 224]               0
#            Conv2d-67          [-1, 1, 224, 224]              17
# ================================================================
# Total params: 1,374,993
# Trainable params: 1,374,993
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 149.11
# Params size (MB): 5.25
# Estimated Total Size (MB): 154.54
# ----------------------------------------------------------------

# %%
class inversePINNs():
    def __init__(self,loads,setType,param):
        self.loss_function = nn.MSELoss(reduction ='mean')
        self.loads = torch.tensor([loads], requires_grad=True).float().to(param['device'])  
        self.loads = nn.Parameter(self.loads)
        self.model = models.UNet(in_channels=1, out_channels=1, factors=2,param=param).to(param['device'])
        self.model.register_parameter('loads',self.loads)
        self.param = param
        self.setType = setType

    def loss_data(self,SampleNum):
        paths = data_Preprocess.getDataPath()  
        MPsNames = data_Preprocess.findTargetFiles_measurements(paths,self.setType,dataType='measurements',param = self.param)
        Data = data_Preprocess.addGaussianNoise(data_Preprocess.transferToTensor(data_Preprocess.loadData_fromFiles(MPsNames[SampleNum])),self.param)
        Trues = Data[:,-1]
        self.MPs = data_Preprocess.generate_Map(MPsNames[SampleNum],self.param).unsqueeze(0)
        self.out = self.model(self.MPs.unsqueeze(0))
        Preds = []
        for i in Data:
            coord = []
            for j in range(len(i[:-1])):
                coord.append(i[j]/self.param['mesh_size'][j])
            Preds.append(self.out[0][0][round(coord[0].item())][round(coord[1].item())])
        Preds = torch.stack(Preds)
        #print (Trues)
        #print(Preds)
        loss_u = self.loss_function(Trues,Preds)
        return loss_u
    
    def loss_PDE(self):
        mesh_size = self.param['mesh_size']
        hx = mesh_size[0]
        hy = mesh_size[1]     
        count = 0
        self.loss_hs = 0
        for i in self.param['HS_region']:
            if count < 3:
                pred_load = torch.mean(torch.abs(self.out[0][0][round(i[0][0].item()/hx):round(i[0][1].item()/hx)+1,round(i[1][0].item()/hy):round(i[1][1].item()/hy)+1]))
                #print (self.out[0][0][round(i[0][0].item()/hx):round(i[0][1].item()/hx)+1,round(i[1][0].item()/hy):round(i[1][1].item()/hy)+1])
                #print (pred_load)
                #print (self.loads[0][count])
                self.loss_hs += torch.abs(self.loads[0][count]-pred_load)
            else:
                pred_load = torch.mean(torch.abs(self.out[0][0][round(i[0][0].item()/hx):round(i[0][1].item()/hx)+1,round(i[1][0].item()/hy):round(i[1][1].item()/hy)+1]))
                #print (pred_load)
                #print (self.loads[0])                
                self.loss_hs += torch.abs(self.loads[0][count-1]-pred_load)                
            count = count + 1
        #print (self.loads)
        self.loss_t_inner = uLoss.loss_T_inner(self.out,self.param)
        self.loss_t_neumann = uLoss.loss_neumann(self.out,self.param)
        self.loss_t_radiation = uLoss.loss_radiation(self.out,self.param)
        self.loss_t_convection = uLoss.loss_convection(self.out,self.param) 
        #print (self.loss_t_inner)
        #print (self.loss_t_neumann)
        #print (self.loss_t_radiation)
        #print (self.loss_t_convection)
        return 1000*self.loss_t_inner+1000*self.loss_t_neumann+1000*self.loss_t_radiation+1000*self.loss_t_convection+100*self.loss_hs
    def loss(self,SampleNum):
        loss_d = self.loss_data(SampleNum)
        loss_p = self.loss_PDE()
        #print (loss_d)
        #print (loss_p)
        return loss_d+loss_p

# %%
loads = [88.0,90.0,66.0,74.0,57.0]
setType = 'Test'
losses = inversePINNs(loads,setType,param)
losses.loss(10)
# Out:
# tensor(34457.8555, device='cuda:0', grad_fn=<AddBackward0>)

# %%
56 79 56 88 43
# Out:
#   Cell In[155], line 1
#     56 79 56 88 43
#        ^
# SyntaxError: invalid syntax

# %%
PINN = inversePINNs(loads,setType,param)
params = list(PINN.model.parameters())
optimizer = torch.optim.Adam(params, lr = 0.005)
for epoch in range(20000):
    optimizer.zero_grad()
    losses = PINN.loss(10)
    losses.backward()
    optimizer.step()
    if (epoch % param['dis_interval'] == 0) or (epoch + 1 == param['epochs']):
        print ('Traing Epoch: {}, loss = {}'.format(epoch,losses))
        print("loads:", PINN.loads)
# Out:
# Traing Epoch: 0, loss = 34457.85546875
# loads: Parameter containing:
# tensor([[87.9950, 89.9950, 65.9950, 73.9950, 56.9950]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 500, loss = 377.2351989746094
# loads: Parameter containing:
# tensor([[87.1964, 89.1348, 65.4483, 73.1650, 56.1244]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 1000, loss = 342.2062072753906
# loads: Parameter containing:
# tensor([[87.1214, 89.0857, 65.4892, 73.1528, 56.1231]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 1500, loss = 223.1727752685547
# loads: Parameter containing:
# tensor([[87.0624, 89.0377, 65.5245, 73.1442, 56.1228]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 2000, loss = 196.66444396972656
# loads: Parameter containing:
# tensor([[87.0091, 89.0030, 65.5504, 73.1421, 56.1319]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 2500, loss = 112.34842681884766
# loads: Parameter containing:
# tensor([[86.9610, 88.9700, 65.5742, 73.1387, 56.1384]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 3000, loss = 134.00843811035156
# loads: Parameter containing:
# tensor([[86.9222, 88.9339, 65.5978, 73.1325, 56.1463]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 3500, loss = 83.53095245361328
# loads: Parameter containing:
# tensor([[86.8797, 88.8952, 65.6223, 73.1391, 56.1448]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 4000, loss = 102.53836822509766
# loads: Parameter containing:
# tensor([[86.8456, 88.8660, 65.6393, 73.1382, 56.1508]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 4500, loss = 145.19227600097656
# loads: Parameter containing:
# tensor([[86.8171, 88.8379, 65.6559, 73.1392, 56.1521]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 5000, loss = 90.66947174072266
# loads: Parameter containing:
# tensor([[86.7842, 88.8106, 65.6720, 73.1444, 56.1516]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 5500, loss = 159.27838134765625
# loads: Parameter containing:
# tensor([[86.7562, 88.7794, 65.6894, 73.1464, 56.1541]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 6000, loss = 97.00188446044922
# loads: Parameter containing:
# tensor([[86.7297, 88.7484, 65.7035, 73.1523, 56.1538]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 6500, loss = 90.81321716308594
# loads: Parameter containing:
# tensor([[86.7055, 88.7271, 65.7139, 73.1549, 56.1557]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 7000, loss = 107.96821594238281
# loads: Parameter containing:
# tensor([[86.6837, 88.6981, 65.7271, 73.1616, 56.1605]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 7500, loss = 122.39570617675781
# loads: Parameter containing:
# tensor([[86.6569, 88.6704, 65.7407, 73.1688, 56.1619]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 8000, loss = 108.34732055664062
# loads: Parameter containing:
# tensor([[86.6329, 88.6465, 65.7524, 73.1711, 56.1596]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 8500, loss = 136.16006469726562
# loads: Parameter containing:
# tensor([[86.6060, 88.6188, 65.7673, 73.1765, 56.1595]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 9000, loss = 77.0119400024414
# loads: Parameter containing:
# tensor([[86.5827, 88.5993, 65.7802, 73.1816, 56.1581]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 9500, loss = 203.76608276367188
# loads: Parameter containing:
# tensor([[86.5636, 88.5759, 65.7928, 73.1863, 56.1572]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 9999, loss = 75.3283462524414
# loads: Parameter containing:
# tensor([[86.5399, 88.5527, 65.8026, 73.1906, 56.1602]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 10000, loss = 83.41365051269531
# loads: Parameter containing:
# tensor([[86.5399, 88.5535, 65.8026, 73.1906, 56.1602]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 10500, loss = 103.55388641357422
# loads: Parameter containing:
# tensor([[86.5221, 88.5330, 65.8110, 73.1923, 56.1606]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 11000, loss = 47.31106948852539
# loads: Parameter containing:
# tensor([[86.5038, 88.5095, 65.8205, 73.2026, 56.1641]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 11500, loss = 77.5880126953125
# loads: Parameter containing:
# tensor([[86.4880, 88.4872, 65.8283, 73.2077, 56.1641]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 12000, loss = 52.25430679321289
# loads: Parameter containing:
# tensor([[86.4694, 88.4647, 65.8355, 73.2140, 56.1686]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 12500, loss = 57.31511688232422
# loads: Parameter containing:
# tensor([[86.4510, 88.4466, 65.8428, 73.2190, 56.1704]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 13000, loss = 106.55896759033203
# loads: Parameter containing:
# tensor([[86.4359, 88.4292, 65.8516, 73.2234, 56.1719]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 13500, loss = 57.276153564453125
# loads: Parameter containing:
# tensor([[86.4196, 88.4068, 65.8591, 73.2263, 56.1793]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 14000, loss = 54.61606216430664
# loads: Parameter containing:
# tensor([[86.4063, 88.3905, 65.8652, 73.2283, 56.1818]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 14500, loss = 44.64443588256836
# loads: Parameter containing:
# tensor([[86.3911, 88.3713, 65.8740, 73.2311, 56.1847]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 15000, loss = 56.33101272583008
# loads: Parameter containing:
# tensor([[86.3768, 88.3531, 65.8802, 73.2356, 56.1866]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 15500, loss = 78.62631225585938
# loads: Parameter containing:
# tensor([[86.3600, 88.3363, 65.8873, 73.2418, 56.1894]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 16000, loss = 54.614742279052734
# loads: Parameter containing:
# tensor([[86.3447, 88.3186, 65.8934, 73.2440, 56.1943]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 16500, loss = 70.80899810791016
# loads: Parameter containing:
# tensor([[86.3323, 88.3017, 65.8996, 73.2475, 56.1980]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 17000, loss = 77.924560546875
# loads: Parameter containing:
# tensor([[86.3186, 88.2849, 65.9029, 73.2509, 56.2053]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 17500, loss = 53.130767822265625
# loads: Parameter containing:
# tensor([[86.3055, 88.2685, 65.9100, 73.2525, 56.2072]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 18000, loss = 46.0756721496582
# loads: Parameter containing:
# tensor([[86.2922, 88.2523, 65.9143, 73.2564, 56.2164]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 18500, loss = 46.171661376953125
# loads: Parameter containing:
# tensor([[86.2773, 88.2355, 65.9195, 73.2600, 56.2154]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 19000, loss = 82.70140838623047
# loads: Parameter containing:
# tensor([[86.2664, 88.2189, 65.9245, 73.2647, 56.2234]], device='cuda:0',
#        requires_grad=True)
# Traing Epoch: 19500, loss = 55.97447967529297
# loads: Parameter containing:
# tensor([[86.2510, 88.2033, 65.9313, 73.2661, 56.2277]], device='cuda:0',
#        requires_grad=True)

# %%
PINN.loads
# Out:
# Parameter containing:
# tensor([[86.2373, 88.1873, 65.9341, 73.2702, 56.2345]], device='cuda:0',
#        requires_grad=True)

# %%
plt.imshow(PINN.out.view(101,101).cpu().detach().numpy(),cmap='rainbow')
plt.colorbar()
